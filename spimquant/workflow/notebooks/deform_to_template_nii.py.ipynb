# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/localscratch/pypoetry_venv/spimquant-FX4pj9UN-py3.11/lib/python3.11/site-packages', '/local/scratch/SPIMquant/spimquant/workflow/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xe1\x11\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cm/cifs/prado/Kelly/data/lightsheet/bids/test_bids/sub-mouse1/micr/sub-mouse1_sample-brain_acq-4x_spim.ome.zarr\x94\x8cjresults/sub-mouse1/warps/sub-mouse1_sample-brain_acq-4x_from-subject_to-gubra_type-ras_desc-affine_xfm.txt\x94\x8cVresults/sub-mouse1/warps/sub-mouse1_sample-brain_acq-4x_from-subject_to-gubra_warp.nii\x94\x8c\'results/tpl-gubra/tpl-gubra_anat.nii.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x08ome_zarr\x94K\x00N\x86\x94\x8c\x07xfm_ras\x94K\x01N\x86\x94\x8c\x08warp_nii\x94K\x02N\x86\x94\x8c\x07ref_nii\x94K\x03N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1b\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h!)}\x94\x8c\x05_name\x94h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bh\x11h\nh\x13h\x0bh\x15h\x0ch\x17h\rub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8ceresults/sub-mouse1/micr/sub-mouse1_sample-brain_acq-4x_stain-abeta_space-gubra_desc-deformnb_spim.nii\x94a}\x94(h\x0f}\x94\x8c\x03nii\x94K\x00N\x86\x94sh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bh2h/ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(K\x00K\x14K\x14K\x14\x87\x94Ne}\x94(h\x0f}\x94(\x8c\rchannel_index\x94K\x00N\x86\x94\x8c\x06chunks\x94K\x01N\x86\x94\x8c\x05zooms\x94K\x02N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bhDK\x00hFhAhHNub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x06mouse1\x94\x8c\x05brain\x94\x8c\x024x\x94\x8c\x05abeta\x94\x8c\x05gubra\x94e}\x94(h\x0f}\x94(\x8c\x07subject\x94K\x00N\x86\x94\x8c\x06sample\x94K\x01N\x86\x94\x8c\x03acq\x94K\x02N\x86\x94\x8c\x05stain\x94K\x03N\x86\x94\x8c\x08template\x94K\x04N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94b\x8c\x07subject\x94hW\x8c\x06sample\x94hXhbhY\x8c\x05stain\x94hZ\x8c\x08template\x94h[ub\x8c\x07threads\x94K\x0c\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x0cK\x01\x8c\x04/tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bh}K\x0ch\x7fK\x01h\x81hzub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bub\x8c\x06config\x94}\x94(\x8c\x08bids_dir\x94\x8c0/cifs/prado/Kelly/data/lightsheet/bids/test_bids\x94\x8c\noutput_dir\x94\x8c\x01.\x94\x8c\x05debug\x94\x89\x8c\x0bderivatives\x94\x89\x8c\x0fanalysis_levels\x94]\x94\x8c\x0bparticipant\x94a\x8c\x19targets_by_analysis_level\x94}\x94\x8c\x0bparticipant\x94]\x94\x8c\x00\x94as\x8c\rpybids_inputs\x94}\x94\x8c\x04spim\x94}\x94(\x8c\x07filters\x94}\x94(\x8c\x06suffix\x94\x8c\x04spim\x94\x8c\x0bacquisition\x94\x8c\x024x\x94\x8c\textension\x94\x8c\x08ome.zarr\x94u\x8c\twildcards\x94]\x94(\x8c\x07subject\x94\x8c\x06sample\x94\x8c\x0bacquisition\x94\x8c\x08staining\x94eus\x8c\nparse_args\x94}\x94(\x8c\x08bids_dir\x94}\x94\x8c\x04help\x94\x8cNThe directory with the input dataset formatted according to the BIDS standard.\x94s\x8c\noutput_dir\x94}\x94\x8c\x04help\x94\x8c\xb5The directory where the output files should be stored. If you are running group level analysis this folder should be prepopulated with the results of the participant level analysis.\x94s\x8c\x0eanalysis_level\x94}\x94(\x8c\x04help\x94\x8c-Level of the analysis that will be performed.\x94\x8c\x07choices\x94h\xa4u\x8c\x13--participant-label\x94}\x94(\x8c\x04help\x94X\'\x01\x00\x00The label(s) of the participant(s) that should be analyzed. The label corresponds to sub-<participant_label> from the BIDS spec (so it does not include "sub-"). If this parameter is not provided all subjects should be analyzed. Multiple participants can be specified with a space separated list.\x94\x8c\x05nargs\x94\x8c\x01+\x94u\x8c\x1b--exclude-participant-label\x94}\x94(\x8c\x04help\x94X\'\x01\x00\x00The label(s) of the participant(s) that should be excluded. The label corresponds to sub-<participant_label> from the BIDS spec (so it does not include "sub-"). If this parameter is not provided all subjects should be analyzed. Multiple participants can be specified with a space separated list.\x94\x8c\x05nargs\x94h\xd1u\x8c\r--derivatives\x94}\x94(\x8c\x04help\x94\x8csPath(s) to a derivatives dataset, for folder(s) that contains multiple derivatives datasets (default: %(default)s) \x94\x8c\x07default\x94\x89\x8c\x05nargs\x94h\xd1u\x8c\x16--skip-bids-validation\x94}\x94(\x8c\x04help\x94\x8c\xd9Skip validation of BIDS dataset. BIDS validation is performed by default using the bids-validator plugin (if installed/enabled) or with the pybids validator implementation (if bids-validator is not installed/enabled).\x94\x8c\x04dest\x94\x8c\x16plugins.validator.skip\x94\x8c\x06action\x94\x8c\nstore_true\x94\x8c\x07default\x94\x89uu\x8c\ncontainers\x94}\x94\x8c\x08spimprep\x94\x8c#docker://khanlab/spimprep-deps:main\x94s\x8c\x04root\x94\x8c\x07results\x94\x8c\x04work\x94\x8c\x04work\x94\x8c\x08ome_zarr\x94}\x94(\x8c\x17max_downsampling_layers\x94K\x04\x8c\x0crechunk_size\x94]\x94(K\x01M\x00\x04M\x00\x04e\x8c\x0escaling_method\x94\x8c\nlocal_mean\x94u\x8c\ttemplates\x94]\x94\x8c\x05gubra\x94a\x8c\x07atlases\x94}\x94(\x8c\x05ABAv3\x94}\x94(\x8c\x04anat\x94\x8c6{workflow.basedir}/../resources/ABAv3/P56_Atlas.nii.gz\x94\x8c\x04dseg\x94\x8c;{workflow.basedir}/../resources/ABAv3/P56_Annotation.nii.gz\x94\x8c\x03lut\x94\x8cC{workflow.basedir}/../resources/ABAv3/labelmapper_ABAv3_to_all.json\x94u\x8c\x05gubra\x94}\x94(\x8c\x04anat\x94\x8cO{workflow.basedir}/../resources/gubra/gubra_template_olf_affine_padABAv3.nii.gz\x94\x8c\x04dseg\x94\x8cP{workflow.basedir}/../resources/gubra/gubra_ano_olf_affine_padABAv3_remap.nii.gz\x94\x8c\x03lut\x94\x8cC{workflow.basedir}/../resources/ABAv3/labelmapper_ABAv3_to_all.json\x94uu\x8c\x0fchannel_mapping\x94}\x94(\x8c\x05abeta\x94K\x00\x8c\x05autof\x94K\x01u\x8c\x08atlasreg\x94}\x94(\x8c\x05stain\x94\x8c\x05autof\x94\x8c\x05level\x94K\x04\x8c\x04desc\x94\x8c\x07N4brain\x94\x8c\x14atlas_prior_for_mask\x94\x8c\x05gubra\x94u\x8c\x07masking\x94}\x94(\x8c\x05gmm_k\x94K\t\x8c\x0cgmm_bg_class\x94K\x01uu\x8c\x04rule\x94\x8c\x19deform_to_template_nii_nb\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c5/local/scratch/SPIMquant/spimquant/workflow/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/local/scratch/SPIMquant/spimquant');
######## snakemake preamble end #########

# %%
# start coding here
snakemake.input
# Out:
# ['/cifs/prado/Kelly/data/lightsheet/bids/test_bids/sub-mouse1/micr/sub-mouse1_sample-brain_acq-4x_spim.ome.zarr',
#  'results/sub-mouse1/warps/sub-mouse1_sample-brain_acq-4x_from-subject_to-gubra_type-ras_desc-affine_xfm.txt',
#  'results/sub-mouse1/warps/sub-mouse1_sample-brain_acq-4x_from-subject_to-gubra_warp.nii',
#  'results/tpl-gubra/tpl-gubra_anat.nii.gz']

# %%
import nibabel as nib
from  ome_zarr_neuro.transform import DaskImage, TransformSpec
from dask.diagnostics import ProgressBar


#member function of floting image
flo_dimg = DaskImage.from_path(snakemake.input.ome_zarr, channels=[snakemake.params.channel_index])
ref_dimg = DaskImage.from_path_as_ref(snakemake.input.ref_nii, channels=[snakemake.params.channel_index],chunks=snakemake.params.chunks,zooms=snakemake.params.zooms)

deform_dimg = flo_dimg.apply_transform(TransformSpec.displacement_from_nifti(snakemake.input.warp_nii),
                    TransformSpec.affine_ras_from_txt(snakemake.input.xfm_ras),
                    ref_dimg=ref_dimg)

# %%
deform_dimg.darr.dask
# Out:
# HighLevelGraph with 3 layers.
# ...
#  0. empty_like-bdbba57558fe2514651cb85f842690a9
#  1. block-info-interp_by_block-774d1cfada3da25f3eebc48e6976b63e
#  2. interp_by_block-774d1cfada3da25f3eebc48e6976b63e

# %%
import dask.array as da
import numpy as np

# %%
darr = da.from_array(np.zeros((456,568,320)),chunks=(20,20,20))
darr
# Out:
# dask.array<array, shape=(456, 568, 320), dtype=float64, chunksize=(20, 20, 20), chunktype=numpy.ndarray>

# %%
snakemake.params.chunks
# Out:
# (20, 20, 20)

# %%
ref_dimg.darr
# Out:
# dask.array<interp_by_block, shape=(1, 456, 568, 320), dtype=float32, chunksize=(1, 255, 255, 255), chunktype=numpy.ndarray>

# %%
deform_dimg.darr.dask
# Out:
# HighLevelGraph with 3 layers.
# ...
#  0. empty_like-d7c165a05c9f7eec31d411c180896121
#  1. block-info-interp_by_block-cee83dcd8eb7fde00174f491d5d14848
#  2. interp_by_block-cee83dcd8eb7fde00174f491d5d14848

# %%
from dask.distributed import Client
client = Client(n_workers=1)  # start distributed scheduler locally.
# Out:
# 2024-03-10 23:28:02,105 - distributed.nanny - WARNING - Worker process still alive after 3.1999980163574224 seconds, killing

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:43989' processes=1 threads=12, memory=47.05 GiB>

# %%
deform_dimg.to_nifti(snakemake.output.nii)#, scheduler='single-threaded')
# Out:
# /localscratch/pypoetry_venv/spimquant-FX4pj9UN-py3.11/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 1.86 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2024-03-10 23:27:01,253 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 32.95 GiB -- Worker memory limit: 47.05 GiB
# 2024-03-10 23:27:11,271 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 36.71 GiB -- Worker memory limit: 47.05 GiB

# %%
with ProgressBar():

    deform_dimg.to_nifti(snakemake.output.nii, scheduler='single-threaded')
